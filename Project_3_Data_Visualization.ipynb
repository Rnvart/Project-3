# %% [markdown]
# <a href="https://colab.research.google.com/github/Rnvart/Project-3/blob/main/Project_3_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
squares = [1, 4, 9, 16, 25]
fix, ax = plt.subplots()  # fig весь рисунок или набор генерируемых диаграмм, ax - одна диаграмма на рисунке
ax.plot(squares,linewidth=3)
# Назначение заголовка диаграммы и меток осей
ax.set_title("Square numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)
# Назначение размера шрифта делений на осях
ax.tick_params(axis='both',labelsize=14)
plt.show()
